# %% [markdown]
# # 0915

# %% [markdown]
# ### complete datasets

# %%
import magic
import scprep
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
filled_logdata_adjusted=pd.read_csv("D:/GEMimp/0915/filled_logdata_adjusted_2.csv",index_col=0)
filled_logdata_adjusted.head(5)

# %%
newfile2=filled_logdata_adjusted
mydata2=newfile2.T
magic_op2 = magic.MAGIC()
emt_magic2 = magic_op2.fit_transform(mydata2)
fmatrix2=emt_magic2.T
ip_file2=fmatrix2
ip_file2.head(5)
# Out:
# Calculating MAGIC...
#   Running MAGIC on 294 cells and 170 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.11 seconds.
#     Calculating KNN search...
#     Calculated KNN search in 0.02 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.15 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.16 seconds.
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.152399                    0.174345
# DLF002                0.314440                    0.196938
# DLF003                0.598661                    0.232464
# DLF004                0.374732                    0.320668
# DLF005                0.237418                    0.126978
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.166613                   0.103221
# ...

# %%
zero_count = (ip_file2 == 0).sum().sum()

total_elements = ip_file2.size
zero_proportion = zero_count / total_elements
zero_proportion
# Out:
# 0.0

# %%
ip_file2.to_csv('D:/GEMimp/0915/outptfile_bymagic_2.csv', index=True)

# %% [markdown]
# ## highly expressed datasets

# %%
import magic
import scprep
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
filled_logdata_adjusted=pd.read_csv("D:/GEMimp/0915/filled_logdata_adjusted_5.csv",index_col=0)
filled_logdata_adjusted.head(5)
# Out:
#       s__Clostridium_sp_L2_50  s__Faecalibacterium_prausnitzii  \
# S158                 0.000000                         4.484016
# S205                 0.004321                         3.734870
# S235                 0.004321                         5.016983
# S244                 0.004321                         4.617804
# S248                 0.000000                         0.000000
#
#       s__Dialister_invisus  s__Dorea_longicatena  s__Ruminococcus_obeum  \
# S158              0.000000                   0.0               4.325131
# S205              0.000000                   0.0               0.000000
# S235              0.000000                   0.0               4.218256
# S244              0.000000                   0.0               0.000000
# S248              3.209297                   0.0               3.801727
#
#       s__Coprococcus_comes  s__Ruminococcus_sp_5_1_39BFAA  \
# S158              0.000000                       0.000000
# ...

# %%
newfile2=filled_logdata_adjusted
mydata2=newfile2.T
magic_op2 = magic.MAGIC()
emt_magic2 = magic_op2.fit_transform(mydata2)
fmatrix2=emt_magic2.T
ip_file2=fmatrix2
ip_file2.head(5)
# Out:
# Calculating MAGIC...
#   Running MAGIC on 193 cells and 53 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.04 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.06 seconds.
#       s__Clostridium_sp_L2_50  s__Faecalibacterium_prausnitzii  \
# S158                 0.324919                         1.148875
# S205                 0.296111                         0.883777
# S235                 0.230752                         1.048424
# S244                 0.207875                         1.082845
# S248                 0.338633                         0.668750
#
#       s__Dialister_invisus  s__Dorea_longicatena  s__Ruminococcus_obeum  \
# S158              0.529465              0.439865               0.943019
# ...

# %%
zero_count = (ip_file2 == 0).sum().sum()

total_elements = ip_file2.size
zero_proportion = zero_count / total_elements
zero_proportion
# Out:
# 0.0

# %%
ip_file2.to_csv('D:/GEMimp/0915/outptfile_bymagic_5.csv', index=True)
