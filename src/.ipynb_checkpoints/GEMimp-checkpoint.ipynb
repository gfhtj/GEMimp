# %% [markdown]
# # 这一块就不要再看了，看下面哪些

# %%
import pandas as pd
#导入50%的0填充数据
rawfile=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/modified_data_experiment_4.csv",index_col=0)
rawfile.head(5)
# Out:
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                    0.004321
# DLF002                5.365408                    0.004321
# DLF003                4.767397                    0.000000
# DLF004                0.000000                    4.222412
# DLF005                4.951198                    0.004321
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.000000                   0.000000
# DLF002                         0.000000                   2.170000
# DLF003                         0.000000                   2.930766
# DLF004                         0.000000                   0.000000
# DLF005                         5.042744                   0.000000
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# DLF001                 0.004321             0.000000               0.000000
# ...

# %%
#change directory to src

from MBIMP import Impute

import pandas as pd

# %%
graph_adj=Impute.GraphBuild(input_file=rawfile,k=5)

# %%
cell_emb=Impute.trainCellEmbeddings(graph_adj)
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 76.43it/s]

# %%
data_imp=Impute.imputation(mbfile=rawfile,embeddingfile=cell_emb,AdjGraph=graph_adj)

# %%
data_imp.head(5)
# Out:
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                    0.004321
# DLF002                5.365408                    0.004321
# DLF003                4.767397                    0.002161
# DLF004                0.000000                    4.222412
# DLF005                4.951198                    0.004321
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.004321                   0.004321
# DLF002                         0.002161                   2.170000
# DLF003                         0.000000                   2.930766
# DLF004                         0.000000                   0.002161
# DLF005                         5.042744                   0.002161
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# DLF001                 0.004321             0.004321               0.000000
# ...

# %%
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/outptfile_bygemimp50.csv', index=True) #插补后
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/outptfile_bygemimp50.csv', index=True)
#
# NameError: name 'data_imp' is not defined

# %%
###log(raw_data - 1.01)

# %% [markdown]
# ### 70%

# %%
#导入70%的0填充数据
rawfile=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/modified_data_experiment_5.csv",index_col=0)
rawfile.head(5)
# Out:
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                         0.0
# DLF002                0.000000                         0.0
# DLF003                0.000000                         0.0
# DLF004                0.000000                         0.0
# DLF005                0.000000                         0.0
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.000000                   0.000000
# DLF002                         0.000000                   2.170000
# DLF003                         0.000000                   0.000000
# DLF004                         4.620816                   2.732934
# DLF005                         0.000000                   2.453710
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# DLF001                      0.0             0.000000               0.000000
# ...

# %%
#change directory to src

from MBIMP import Impute

import pandas as pd

# %%
graph_adj=Impute.GraphBuild(input_file=rawfile,k=5)

# %%
cell_emb=Impute.trainCellEmbeddings(graph_adj)
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 44.83it/s]

# %%
data_imp=Impute.imputation(mbfile=rawfile,embeddingfile=cell_emb,AdjGraph=graph_adj)

# %%
data_imp.head(5)
# Out:
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                         0.0
# DLF002                0.000000                         0.0
# DLF003                0.004321                         0.0
# DLF004                0.000000                         0.0
# DLF005                0.000000                         0.0
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.000000                   0.000000
# DLF002                         0.000000                   2.170000
# DLF003                         0.000000                   0.000000
# DLF004                         4.620816                   2.732934
# DLF005                         0.002161                   2.453710
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# DLF001                      0.0             0.000000               0.000000
# ...

# %%
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/outptfile_bygemimp70.csv', index=True) #插补后

# %% [markdown]
# ## 现在导入有规律的插入0的数据，50%，70%，90%的比例

# %%
import pandas as pd
#导入50%的0填充数据
rawfile=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/Yzi_0.5.csv",index_col=0)
rawfile[rawfile == rawfile.iloc[0, 0]] = 0

rawfile.head(5)
# Out:
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.000000                    0.000000
# DLF002                0.000000                    0.000000
# DLF003                4.767397                    0.000000
# DLF004                4.174560                    4.222412
# DLF005                0.000000                    0.000000
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.000000                   0.000000
# DLF002                         5.157808                   0.000000
# DLF003                         5.057290                   2.930766
# DLF004                         4.620816                   2.732934
# DLF005                         0.000000                   0.000000
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# DLF001                 0.000000             0.000000               5.377047
# ...

# %%
rawfile.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0829/Yzi_0.5.csv', index=True)

# %%
rawfile50=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/0829/Yzi_0.5.csv",index_col=0)

# %%
rawfile50=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/Yzi_0.5.csv",index_col=0)

# %%
rawfile50.head()
# Out:
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                    0.004321
# DLF002                0.004321                    0.004321
# DLF003                4.767397                    4.355369
# DLF004                0.004321                    0.004321
# DLF005                4.951198                    0.004321
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.004321                   0.004321
# DLF002                         5.157808                   0.004321
# DLF003                         0.004321                   2.930766
# DLF004                         0.004321                   0.004321
# DLF005                         0.004321                   2.453710
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# DLF001                 0.004321             2.064384               5.377047
# ...

# %%
#change directory to src

from MBIMP import Impute

import pandas as pd

# %%
graph_adj=Impute.GraphBuild(input_file=rawfile,k=3) # 从5改成3
#graph_adj=Impute.GraphBuild(input_file=rawfile,k=5) # 从5改成3

# %%
cell_emb=Impute.trainCellEmbeddings(graph_adj)
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 99.24it/s]

# %%
data_imp=Impute.imputation(mbfile=rawfile,embeddingfile=cell_emb,AdjGraph=graph_adj)

# %%
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0829/outptfile_bygemimp0.5_ceshi.csv', index=True) #插补后

# %%
data_imp.head()
# Out:
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                    0.004321
# DLF002                0.004321                    0.004321
# DLF003                4.767397                    4.355369
# DLF004                0.004321                    0.004321
# DLF005                4.951198                    0.004321
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.004321                   0.004321
# DLF002                         5.157808                   0.004321
# DLF003                         0.004321                   2.930766
# DLF004                         0.004321                   0.004321
# DLF005                         0.004321                   2.453710
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# DLF001                 0.004321             2.064384               5.377047
# ...

# %% [markdown]
# ### 接着70%

# %%
import pandas as pd
#导入70%的0填充数据
rawfile=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/Yzi_0.7.csv",index_col=0)
rawfile.head(5)
#change directory to src

from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=rawfile,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp=Impute.imputation(mbfile=rawfile,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0829/outptfile_bygemimp0.7.csv', index=True) #插补后
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 86.35it/s]

# %% [markdown]
# ### 90%

# %%
import pandas as pd
#导入90%的0填充数据
rawfile=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/Yzi_0.9.csv",index_col=0)
rawfile[rawfile == rawfile.iloc[0, 0]] = 0
rawfile.head(5)
#change directory to src

from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=rawfile,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp=Impute.imputation(mbfile=rawfile,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0829/outptfile_bygemimp0.9_2.csv', index=True) #插补后
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 24.48it/s]

# %%
data_imp.head()
# Out:
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                    0.004321
# DLF002                5.365408                    0.004321
# DLF003                4.767397                    4.355369
# DLF004                4.174560                    4.222412
# DLF005                4.951198                    0.004321
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.004321                   0.004321
# DLF002                         5.157808                   2.170000
# DLF003                         5.057290                   2.930766
# DLF004                         4.620816                   2.732934
# DLF005                         5.042744                   2.453710
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# DLF001                 0.004321             0.004321               5.377047
# ...

# %%
##
#gemimp插补的数据结果是'D:/阅读文献同步文件夹/mbImpute code/0825new/0829/outptfile_bygemimp0.9.csv'

# %% [markdown]
# ### 现在导入有规律插补的30,20,10数据

# %%
import pandas as pd
#导入30%的0填充数据
rawfile=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/0829/Yzi_0.3.csv",index_col=0)
rawfile.head(5)
#change directory to src

from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=rawfile,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp=Impute.imputation(mbfile=rawfile,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0829/outptfile_bygemimp0.3.csv', index=True) #插补后
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 83.54it/s]

# %%
import pandas as pd
#导入20%的0填充数据
rawfile=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/0829/Yzi_0.2.csv",index_col=0)
rawfile.head(5)
#change directory to src

from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=rawfile,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp=Impute.imputation(mbfile=rawfile,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0829/outptfile_bygemimp0.2.csv', index=True) #插补后
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 81.76it/s]

# %%
import pandas as pd
#导入10%的0填充数据
rawfile=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/0829/Yzi_0.1.csv",index_col=0)
rawfile.head(5)
#change directory to src

from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=rawfile,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp=Impute.imputation(mbfile=rawfile,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0829/outptfile_bygemimp0.1.csv', index=True) #插补后
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 69.31it/s]

# %% [markdown]
# ## 新的数据在做插补，simulation 1

# %%
import pandas as pd
#导入50%的0填充数据
rawfile=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/0829/Yzi_simu1_0.5.csv",index_col=0)
rawfile.head(5)
# Out:
#       s__Clostridium_sp_L2_50  s__Faecalibacterium_prausnitzii  \
# S158                 4.709704                         0.004321
# S205                 0.004321                         3.734870
# S235                 0.004321                         5.016983
# S244                 0.004321                         0.004321
# S248                 0.004321                         0.004321
#
#       s__Dialister_invisus  s__Dorea_longicatena  s__Ruminococcus_obeum  \
# S158              0.004321              0.004321               0.004321
# S205              0.004321              0.004321               0.004321
# S235              0.004321              0.004321               4.218256
# S244              4.635372              4.473081               0.004321
# S248              0.004321              0.004321               0.004321
#
#       s__Coprococcus_comes  s__Ruminococcus_sp_5_1_39BFAA  \
# S158              3.647634                       4.308865
# ...

# %%
from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=rawfile,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp=Impute.imputation(mbfile=rawfile,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0829/simu1/outptfile_simu1_bygemimp0.5.csv', index=True) #插补后
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 91.66it/s]

# %%
#70%
import pandas as pd
#导入50%的0填充数据
rawfile=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/0829/Yzi_simu1_0.7.csv",index_col=0)
rawfile.head(5)
from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=rawfile,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp=Impute.imputation(mbfile=rawfile,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0829/simu1/outptfile_simu1_bygemimp0.7.csv', index=True) #插补后
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 99.58it/s]

# %%
#70%
import pandas as pd
#导入50%的0填充数据
rawfile=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/0829/Yzi_simu1_0.9.csv",index_col=0)
rawfile.head(5)
from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=rawfile,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp=Impute.imputation(mbfile=rawfile,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0829/simu1/outptfile_simu1_bygemimp0.9.csv', index=True) #插补后
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 92.66it/s]

# %% [markdown]
# ###  新的数据simulation1 的10%，30%缺失

# %%
import pandas as pd
#导入30%的0填充数据
rawfile=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/0829/Yzi_simu1_0.3.csv",index_col=0)
rawfile.head(5)
# Out:
#       s__Clostridium_sp_L2_50  s__Faecalibacterium_prausnitzii  \
# S158                 0.004321                         4.484016
# S205                 0.004321                         0.004321
# S235                 0.004321                         0.004321
# S244                 0.004321                         4.617804
# S248                 0.004321                         4.808831
#
#       s__Dialister_invisus  s__Dorea_longicatena  s__Ruminococcus_obeum  \
# S158              4.688561              4.045549               4.325131
# S205              4.600074              0.004321               3.380959
# S235              4.909970              0.004321               0.004321
# S244              0.004321              0.004321               3.761920
# S248              3.209297              4.634419               3.801727
#
#       s__Coprococcus_comes  s__Ruminococcus_sp_5_1_39BFAA  \
# S158              3.647634                       4.308865
# ...

# %%
from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=rawfile,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp=Impute.imputation(mbfile=rawfile,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0829/simu1/outptfile_simu1_bygemimp0.3.csv', index=True) #插补后
# Out:
# ...
# Generating walks (CPU: 1): 100%|██████████████████████████████████████████████████████| 20/20 [00:00<00:00, 105.12it/s]

# %%
import pandas as pd
#导入10%的0填充数据
rawfile=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/0829/Yzi_simu1_0.1.csv",index_col=0)
rawfile.head(5)
from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=rawfile,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp=Impute.imputation(mbfile=rawfile,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0829/simu1/outptfile_simu1_bygemimp0.1.csv', index=True) #插补后
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 58.40it/s]

# %% [markdown]
# ## 测序深度做插补

# %%
#2000
from MBIMP import Impute
import pandas as pd
#simudata2000=pd.read_csv( 'D:/阅读文献同步文件夹/mbImpute code/0825new/0829/simu2000_0.5.csv',index_col=0)  
#simudata2000=pd.read_csv( 'D:/阅读文献同步文件夹/mbImpute code/0825new/0829/simu2000_0.5.csv',index_col=0) 

simudata2000=pd.read_csv( 'D:/阅读文献同步文件夹/mbImpute code/0825new/0829/sequencing_depth/simudata2000.csv',index_col=0)
simudata2000.head()
# Out:
#           Sample1  Sample2  Sample3  Sample4  Sample5  Sample6  Sample7  \
# Feature1       28        0        0        0        0        0        0
# Feature2        0        0        0        0        0        0        0
# Feature3        0        0        0        0        0        0        0
# Feature4        0        0        0        0        0        0        0
# Feature5        0        0        0        0        0        0        0
#
#           Sample8  Sample9  Sample10  ...  Sample41  Sample42  Sample43  \
# Feature1        3        0         0  ...        28         5         0
# Feature2        0        0         0  ...         0         0         0
# Feature3        0        0         0  ...         0         0         0
# Feature4        0        0         0  ...         0         0         0
# Feature5        0        0         0  ...         0         0         0
#
#           Sample44  Sample45  Sample46  Sample47  Sample48  Sample49  Sample50
# ...

# %%
#simudata2000[simudata2000 == simudata2000.iloc[0, 0]] = 0

# %%
#simudata2000.head()
# Out:
#            Sample1   Sample2   Sample3   Sample4   Sample5   Sample6  \
# Feature1  0.000000  0.303196  0.000000  1.579898  0.000000  0.000000
# Feature2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Feature3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Feature4  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Feature5  0.478566  0.000000  1.903144  0.000000  1.000434  1.361917
#
#            Sample7   Sample8   Sample9  Sample10  ...  Sample41  Sample42  \
# Feature1  0.000000  0.778874  0.845718       0.0  ...  0.303196  0.000000
# Feature2  0.699838  0.000000  0.000000       0.0  ...  0.303196  0.000000
# Feature3  0.000000  0.000000  0.000000       0.0  ...  0.000000  0.000000
# Feature4  0.000000  0.000000  0.000000       0.0  ...  0.000000  0.000000
# Feature5  0.603144  0.603144  0.000000       0.0  ...  0.000000  1.114277
#
#           Sample43  Sample44  Sample45  Sample46  Sample47  Sample48  \
# ...

# %%
graph_adj2000=Impute.GraphBuild(input_file=simudata2000,k=3)

# %%
cell_emb2000=Impute.trainCellEmbeddings(graph_adj2000)
# Out:
# ...
# Generating walks (CPU: 1): 100%|██████████████████████████████████████████████████████| 20/20 [00:00<00:00, 999.12it/s]

# %%
simudata2000_byGEMimp=Impute.imputation(mbfile=simudata2000,embeddingfile=cell_emb2000,AdjGraph=graph_adj2000)

# %%
simudata2000_byGEMimp.head()
# Out:
#            Sample1   Sample2   Sample3   Sample4   Sample5   Sample6  \
# Feature1  0.004321  0.303196  0.004321  0.000000  0.004321  0.000000
# Feature2  0.002161  0.000000  0.004321  0.004321  0.004321  0.004321
# Feature3  0.004321  0.000000  0.004321  0.002161  0.004321  0.000000
# Feature4  0.000000  0.000000  0.002161  0.004321  0.004321  0.002161
# Feature5  0.478566  0.004321  1.903144  0.151598  0.002161  1.361917
#
#            Sample7   Sample8   Sample9  Sample10  ...  Sample41  Sample42  \
# Feature1  0.004321  0.000000  0.845718  0.000000  ...  0.303196  0.000000
# Feature2  0.699838  0.004321  0.004321  0.004321  ...  0.303196  0.004321
# Feature3  0.004321  0.004321  0.004321  0.004321  ...  0.004321  0.004321
# Feature4  0.000000  0.004321  0.000000  0.004321  ...  0.004321  0.004321
# Feature5  0.000000  0.603144  0.000000  0.000000  ...  0.000000  1.114277
#
#           Sample43  Sample44  Sample45  Sample46  Sample47  Sample48  \
# ...

# %%
simudata2000_byGEMimp[simudata2000_byGEMimp == 0] = np.log10(1.01)

# %%
simudata2000_byGEMimp.head(10)
# Out:
#             Sample1   Sample2   Sample3   Sample4   Sample5   Sample6  \
# Feature1   0.004321  0.303196  0.004321  0.004321  0.004321  0.004321
# Feature2   0.002161  0.004321  0.004321  0.004321  0.004321  0.004321
# Feature3   0.004321  0.004321  0.004321  0.002161  0.004321  0.004321
# Feature4   0.004321  0.004321  0.002161  0.004321  0.004321  0.002161
# Feature5   0.478566  0.004321  1.903144  0.151598  0.002161  1.361917
# Feature6   0.002161  0.004321  1.612890  0.004321  0.004321  1.591176
# Feature7   0.004321  0.004321  0.004321  1.929470  0.004321  0.004321
# Feature8   0.004321  0.004321  2.068223  0.004321  0.845718  0.004321
# Feature9   0.004321  0.004321  0.004321  0.002161  0.004321  0.004321
# Feature10  0.004321  0.004321  0.004321  0.002161  0.004321  0.004321
#
#             Sample7   Sample8   Sample9  Sample10  ...  Sample41  Sample42  \
# Feature1   0.004321  0.004321  0.845718  0.004321  ...  0.303196  0.004321
# ...

# %%
rawdata2000=pd.read_csv( 'D:/paper/simulated_data/simudata2000.csv',index_col=0)
rawdata2000.head()
# Out:
#           Sample1  Sample2  Sample3  Sample4  Sample5  Sample6  Sample7  \
# Feature1        0        1        0       37        0        0        0
# Feature2        0        0        0        0        0        0        4
# Feature3        0        0        0        0        0        0        0
# Feature4        0        0      740        0        0        0        0
# Feature5        2        0       79       14        9       22        3
#
#           Sample8  Sample9  Sample10  ...  Sample41  Sample42  Sample43  \
# Feature1        5        6         4  ...         1         0         0
# Feature2        0        0         0  ...         1         0         6
# Feature3        0        0         0  ...         0         0         0
# Feature4        0        0         0  ...         0         0         0
# Feature5        3        0         0  ...         0        12        35
#
#           Sample44  Sample45  Sample46  Sample47  Sample48  Sample49  Sample50
# ...

# %%
rawdata2000 = np.log10(rawdata2000+1.01)
rawdata2000.head(10)
# Out:
#             Sample1   Sample2   Sample3   Sample4   Sample5   Sample6  \
# Feature1   0.004321  0.303196  0.004321  1.579898  0.004321  0.004321
# Feature2   0.004321  0.004321  0.004321  0.004321  0.004321  0.004321
# Feature3   0.004321  0.004321  0.004321  0.004321  0.004321  0.004321
# Feature4   0.004321  0.004321  2.869824  0.004321  0.004321  0.004321
# Feature5   0.478566  0.004321  1.903144  1.176381  1.000434  1.361917
# Feature6   0.004321  0.004321  1.612890  0.004321  0.004321  1.591176
# Feature7   0.004321  0.004321  0.004321  1.929470  0.004321  0.004321
# Feature8   0.603144  0.004321  2.068223  0.954725  0.845718  0.004321
# Feature9   0.004321  0.004321  0.004321  0.004321  0.004321  0.004321
# Feature10  0.004321  0.004321  0.004321  0.004321  0.004321  0.004321
#
#             Sample7   Sample8   Sample9  Sample10  ...  Sample41  Sample42  \
# Feature1   0.004321  0.778874  0.845718  0.699838  ...  0.303196  0.004321
# ...

# %%
#import numpy as np
#simudata2000_byGEMimp[simudata2000_byGEMimp == 0] = np.log10(1.01)

# %%
#import numpy as np

# 比较两个数据框的数组表示是否完全相同
#are_equal = np.array_equal(simudata2000.values, simudata2000_byGEMimp.values)
#print(are_equal)  # 如果完全相同，将输出 True，否则输出 False
# Out:
# False

# %%
# 保存修改后的数据框到文件
simudata2000_byGEMimp.to_csv(f'D:/阅读文献同步文件夹/mbImpute code/0825new/0829/sequencing_depth/simudata2000_byGEMimp_0.5.csv', index=True)##GEMimp插补的50%的缺失的生成数据数据

# %%
#5000
from MBIMP import Impute
import pandas as pd
#simudata5000=pd.read_csv( 'D:/阅读文献同步文件夹/mbImpute code/0825new/0829/simu5000_0.5.csv',index_col=0)  
simudata5000=pd.read_csv( 'D:/阅读文献同步文件夹/mbImpute code/0825new/0829/simu5000_0.5.csv',index_col=0) 
simudata5000.head()
# Out:
#            Sample1   Sample2   Sample3   Sample4   Sample5   Sample6  \
# Feature1  0.000000  0.004321  0.000000  0.004321  0.000000  0.004321
# Feature2  0.000000  0.004321  0.004321  0.004321  0.903633  0.000000
# Feature3  0.000000  0.000000  0.000000  0.000000  0.004321  0.004321
# Feature4  0.004321  1.826140  0.000000  0.000000  0.004321  0.004321
# Feature5  0.004321  0.004321  0.004321  0.004321  0.000000  0.000000
#
#            Sample7   Sample8   Sample9  Sample10  ...  Sample41  Sample42  \
# Feature1  0.004321  0.000000  0.000000  0.004321  ...  0.000000  0.004321
# Feature2  0.303196  0.000000  0.004321  0.004321  ...  0.903633  0.845718
# Feature3  0.004321  0.004321  0.004321  0.000000  ...  0.004321  0.000000
# Feature4  0.004321  0.000000  0.004321  0.004321  ...  0.004321  0.004321
# Feature5  0.004321  0.004321  0.000000  0.004321  ...  0.004321  0.004321
#
#           Sample43  Sample44  Sample45  Sample46  Sample47  Sample48  \
# ...

# %%
#simudata5000[simudata5000 == simudata5000.iloc[0, 1]] = 0
graph_adj5000=Impute.GraphBuild(input_file=simudata5000,k=3)
cell_emb5000=Impute.trainCellEmbeddings(graph_adj5000)

simudata5000_byGEMimp=Impute.imputation(mbfile=simudata5000,embeddingfile=cell_emb5000,AdjGraph=graph_adj5000)
#import numpy as np
simudata5000_byGEMimp[simudata5000_byGEMimp == 0] = np.log10(1.01)
# 保存修改后的数据框到文件
simudata5000_byGEMimp.to_csv(f'D:/阅读文献同步文件夹/mbImpute code/0825new/0829/sequencing_depth/simudata5000_byGEMimp_0.5.csv', index=True)##GEMimp插补的50%的缺失的生成数据数据
# Out:
# ...
# Generating walks (CPU: 1): 100%|██████████████████████████████████████████████████████| 20/20 [00:00<00:00, 898.21it/s]

# %%
simudata5000_byGEMimp.head()
# Out:
#            Sample1   Sample2   Sample3   Sample4   Sample5   Sample6  \
# Feature1  0.004321  0.004321  0.002161  0.004321  0.004321  0.004321
# Feature2  0.002161  0.004321  0.004321  0.004321  0.903633  0.004321
# Feature3  0.002161  0.004321  0.002161  0.002161  0.004321  0.004321
# Feature4  0.004321  1.826140  0.004321  0.002161  0.004321  0.004321
# Feature5  0.004321  0.004321  0.004321  0.004321  0.002161  0.002161
#
#            Sample7   Sample8   Sample9  Sample10  ...  Sample41  Sample42  \
# Feature1  0.004321  0.004321  0.004321  0.004321  ...  0.004321  0.004321
# Feature2  0.303196  0.303196  0.004321  0.004321  ...  0.903633  0.845718
# Feature3  0.004321  0.004321  0.004321  0.004321  ...  0.004321  0.004321
# Feature4  0.004321  0.004321  0.004321  0.004321  ...  0.004321  0.004321
# Feature5  0.004321  0.004321  0.004321  0.004321  ...  0.004321  0.004321
#
#           Sample43  Sample44  Sample45  Sample46  Sample47  Sample48  \
# ...

# %%
#import numpy as np

# 比较两个数据框的数组表示是否完全相同
#are_equal = np.array_equal(simudata5000.values, simudata5000_byGEMimp.values)
#print(are_equal)  # 如果完全相同，将输出 True，否则输出 False
# Out:
# False

# %%
#10000
from MBIMP import Impute
import pandas as pd
#simudata10000=pd.read_csv( 'D:/阅读文献同步文件夹/mbImpute code/0825new/0829/simu10000_0.5.csv',index_col=0)  
simudata10000=pd.read_csv( 'D:/阅读文献同步文件夹/mbImpute code/0825new/0829/simu10000_0.5.csv',index_col=0) 
simudata10000.head()
# Out:
#            Sample1   Sample2   Sample3   Sample4   Sample5   Sample6  \
# Feature1  0.000000  0.000000  0.004321  0.000000  0.004321  0.000000
# Feature2  1.415140  0.000000  0.004321  0.303196  1.114277  1.995679
# Feature3  0.000000  0.000000  0.000000  0.004321  0.004321  0.000000
# Feature4  0.000000  2.152319  0.004321  0.004321  0.000000  0.000000
# Feature5  0.004321  0.000000  0.000000  0.004321  0.000000  0.000000
#
#            Sample7   Sample8   Sample9  Sample10  ...  Sample41  Sample42  \
# Feature1  0.000000  0.000000  0.004321  0.000000  ...  0.478566  0.004321
# Feature2  0.000000  0.000000  0.004321  0.004321  ...  0.000000  1.114277
# Feature3  0.000000  0.000000  0.000000  0.004321  ...  0.004321  0.004321
# Feature4  0.004321  0.004321  0.000000  0.004321  ...  0.303196  0.000000
# Feature5  0.004321  0.000000  0.004321  0.000000  ...  0.000000  0.004321
#
#           Sample43  Sample44  Sample45  Sample46  Sample47  Sample48  \
# ...

# %%
#simudata10000[simudata10000 == simudata10000.iloc[0, 1]] = 0
graph_adj10000=Impute.GraphBuild(input_file=simudata10000,k=3)
cell_emb10000=Impute.trainCellEmbeddings(graph_adj10000)

simudata10000_byGEMimp=Impute.imputation(mbfile=simudata10000,embeddingfile=cell_emb10000,AdjGraph=graph_adj10000)
#import numpy as np
simudata10000_byGEMimp[simudata10000_byGEMimp == 0] = np.log10(1.01)
# 保存修改后的数据框到文件
simudata10000_byGEMimp.to_csv(f'D:/阅读文献同步文件夹/mbImpute code/0825new/0829/sequencing_depth/simudata10000_byGEMimp_0.5.csv', index=True)##GEMimp插补的50%的缺失的生成数据数据
# Out:
# ...
# Generating walks (CPU: 1): 100%|█████████████████████████████████████████████████████| 20/20 [00:00<00:00, 1004.49it/s]

# %%
simudata10000_byGEMimp.head()
# Out:
#            Sample1   Sample2   Sample3   Sample4   Sample5   Sample6  \
# Feature1  0.002161  0.004321  0.004321  0.002161  0.004321  0.004321
# Feature2  1.415140  0.004321  0.004321  0.303196  1.114277  1.995679
# Feature3  0.004321  0.004321  0.004321  0.004321  0.004321  0.004321
# Feature4  0.004321  2.152319  0.004321  0.004321  0.002161  0.004321
# Feature5  0.004321  0.004321  0.004321  0.004321  0.002161  0.004321
#
#            Sample7   Sample8   Sample9  Sample10  ...  Sample41  Sample42  \
# Feature1  0.004321  0.153759  0.004321  0.002161  ...  0.478566  0.004321
# Feature2  0.004321  0.004321  0.004321  0.004321  ...  0.004321  1.114277
# Feature3  0.004321  0.004321  0.004321  0.004321  ...  0.004321  0.004321
# Feature4  0.004321  0.004321  0.004321  0.004321  ...  0.303196  0.004321
# Feature5  0.004321  0.004321  0.004321  0.004321  ...  0.002161  0.004321
#
#           Sample43  Sample44  Sample45  Sample46  Sample47  Sample48  \
# ...

# %%
import numpy as np

# 比较两个数据框的数组表示是否完全相同
are_equal = np.array_equal(simudata10000.values, simudata10000_byGEMimp.values)
print(are_equal)  # 如果完全相同，将输出 True，否则输出 False
# Out:
# False

# %% [markdown]
# # 0915修改

# %%
import pandas as pd
#导入30%的0填充数据
filled_logdata_adjusted=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/0915/filled_logdata_adjusted_5.csv",index_col=0)
filled_logdata_adjusted.head(5)
#change directory to src
#import numpy as np
#filled_logdata_adjusted[filled_logdata_adjusted ==filled_logdata_adjusted.iloc[1, 0]] = 0
#filled_logdata_adjusted.head(5)
# Out:
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                    0.004321
# DLF002                0.000000                    0.000000
# DLF003                4.767397                    0.000000
# DLF004                0.000000                    4.222412
# DLF005                0.000000                    0.000000
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.004321                        0.0
# DLF002                         5.157808                        0.0
# DLF003                         5.057290                        0.0
# DLF004                         4.620816                        0.0
# DLF005                         5.042744                        0.0
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# DLF001                 0.000000             0.000000                    0.0
# ...

# %%
zero_count = (filled_logdata_adjusted == 0).sum().sum()

# 计算数据框的总元素数量
total_elements = filled_logdata_adjusted.size
# 计算0值的比例
zero_proportion = zero_count / total_elements
zero_proportion
# Out:
# 0.6575430172068828

# %%
from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=filled_logdata_adjusted,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp=Impute.imputation(mbfile=filled_logdata_adjusted,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp.head()
#data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0829/outptfile_bygemimp0.3.csv', index=True) #插补后
# Out:
# ...
# Generating walks (CPU: 1): 100%|██████████████████████████████████████████████████████| 20/20 [00:00<00:00, 192.94it/s]
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                    0.004321
# DLF002                0.000864                    0.000000
# DLF003                4.767397                    0.609364
# DLF004                0.000000                    4.222412
# DLF005                0.264881                    0.639928
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.004321                   0.000864
# DLF002                         5.157808                   0.000000
# DLF003                         5.057290                   0.000864
# DLF004                         4.620816                   0.001729
# DLF005                         5.042744                   0.394066
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# ...

# %%
zero_count = (data_imp == 0).sum().sum()

# 计算数据框的总元素数量
total_elements = data_imp.size
# 计算0值的比例
zero_proportion = zero_count / total_elements
zero_proportion
# Out:
# 0.14495798319327732

# %%
graph_adj=Impute.GraphBuild(input_file=data_imp,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp2=Impute.imputation(mbfile=data_imp,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp2.head()
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 94.07it/s]
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                    0.000720
# DLF002                0.000720                    0.023493
# DLF003                4.767397                    0.044022
# DLF004                4.174560                    0.000720
# DLF005                0.000720                    0.000720
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.004321                   0.004321
# DLF002                         0.160753                   0.001440
# DLF003                         0.000000                   0.000720
# DLF004                         4.620816                   2.732934
# DLF005                         0.031341                   2.453710
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# ...

# %%
zero_count = (data_imp2 == 0).sum().sum()

# 计算数据框的总元素数量
total_elements = data_imp2.size
# 计算0值的比例
zero_proportion = zero_count / total_elements
zero_proportion
# Out:
# 0.1166185877336009

# %%
graph_adj=Impute.GraphBuild(input_file=data_imp2,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp3=Impute.imputation(mbfile=data_imp2,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp3.head()
zero_count = (data_imp3 == 0).sum().sum()

# 计算数据框的总元素数量
total_elements = data_imp3.size
# 计算0值的比例
zero_proportion = zero_count / total_elements
zero_proportion
# Out:
# ...
# Generating walks (CPU: 1): 100%|██████████████████████████████████████████████████████| 20/20 [00:00<00:00, 100.90it/s]
# 0.053229650068982816

# %%
graph_adj=Impute.GraphBuild(input_file=data_imp3,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp4=Impute.imputation(mbfile=data_imp3,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp4.head()
zero_count = (data_imp4 == 0).sum().sum()

# 计算数据框的总元素数量
total_elements = data_imp4.size
# 计算0值的比例
zero_proportion = zero_count / total_elements
zero_proportion
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 98.67it/s]
# 0.031493791546469335

# %%
import numpy as np
data_imp4[data_imp4 == 0] = np.log10(1.01)

# %%
import numpy as np
data_imp[data_imp == 0] = np.log10(1.01)
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0915/outptfile_bygemimp_5.csv', index=True) #插补后

# %%
from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=filled_logdata_adjusted,k=3) # 从5改成3
cell_emb0=Impute.trainCellEmbeddings(graph_adj)
cell_emb1=Impute.trainCellEmbeddings(graph_adj,P=0.25,Q=4)
cell_emb2=Impute.trainCellEmbeddings(graph_adj,P=0.25,Q=2)
cell_emb3=Impute.trainCellEmbeddings(graph_adj,P=0.5,Q=4)
cell_emb4=Impute.trainCellEmbeddings(graph_adj,P=1,Q=4)
data_imp=Impute.imputation(mbfile=filled_logdata_adjusted,embeddingfile=cell_emb0,AdjGraph=graph_adj)
data_imp1=Impute.imputation(mbfile=filled_logdata_adjusted,embeddingfile=cell_emb1,AdjGraph=graph_adj)
data_imp2=Impute.imputation(mbfile=filled_logdata_adjusted,embeddingfile=cell_emb2,AdjGraph=graph_adj)
data_imp3=Impute.imputation(mbfile=filled_logdata_adjusted,embeddingfile=cell_emb3,AdjGraph=graph_adj)
data_imp4=Impute.imputation(mbfile=filled_logdata_adjusted,embeddingfile=cell_emb4,AdjGraph=graph_adj)


#graph_adj=Impute.GraphBuild(input_file=filled_logdata_adjusted,k=3) # 从5改成3
#cell_emb=Impute.trainCellEmbeddings(graph_adj)
# Out:
# ...
# Generating walks (CPU: 1): 100%|██████████████████████████████████████████████████████| 20/20 [00:00<00:00, 141.21it/s]

# %%
import numpy as np
data_imp[data_imp == 0] = np.log10(1.01)
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0915/outptfile_bygemimp_50.csv', index=True) #插补后
data_imp1[data_imp1 == 0] = np.log10(1.01)
data_imp1.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0915/outptfile_bygemimp_51.csv', index=True) #插补后
data_imp2[data_imp2 == 0] = np.log10(1.01)
data_imp2.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0915/outptfile_bygemimp_52.csv', index=True) #插补后
data_imp3[data_imp3 == 0] = np.log10(1.01)
data_imp3.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0915/outptfile_bygemimp_53.csv', index=True) #插补后
data_imp4[data_imp4 == 0] = np.log10(1.01)
data_imp4.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0915/outptfile_bygemimp_54.csv', index=True) #插补后

# %% [markdown]
# ### 高表达

# %%
import pandas as pd
#导入30%的0填充数据
filled_logdata_adjusted=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/0915/filled_logdata_adjusted_52.csv",index_col=0)
filled_logdata_adjusted.head(5)
# Out:
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                         0.0
# DLF002                0.000000                         0.0
# DLF003                4.767397                         0.0
# DLF004                4.174560                         0.0
# DLF005                0.000000                         0.0
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.004321                   0.004321
# DLF002                         0.000000                   0.000000
# DLF003                         0.000000                   0.000000
# DLF004                         4.620816                   2.732934
# DLF005                         0.000000                   2.453710
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# DLF001                      0.0             0.000000               0.000000
# ...

# %%
zero_count = (filled_logdata_adjusted == 0).sum().sum()

# 计算数据框的总元素数量
total_elements = filled_logdata_adjusted.size
# 计算0值的比例
zero_proportion = zero_count / total_elements
zero_proportion
# Out:
# 0.7797817634516493

# %%
from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=filled_logdata_adjusted,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp=Impute.imputation(mbfile=filled_logdata_adjusted,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp.head()
#data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0829/outptfile_bygemimp0.3.csv', index=True) #插补后
# Out:
# ...
# Generating walks (CPU: 1): 100%|██████████████████████████████████████████████████████| 20/20 [00:00<00:00, 103.59it/s]
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                     0.00072
# DLF002                0.000720                     0.00000
# DLF003                4.767397                     0.00000
# DLF004                4.174560                     0.00072
# DLF005                0.000720                     0.00072
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.004321                   0.004321
# DLF002                         0.000000                   0.001440
# DLF003                         0.000000                   0.000720
# DLF004                         4.620816                   2.732934
# DLF005                         0.000000                   2.453710
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# ...

# %%
zero_count = (data_imp == 0).sum().sum()

# 计算数据框的总元素数量
total_elements = data_imp.size
# 计算0值的比例
zero_proportion = zero_count / total_elements
zero_proportion
# Out:
# 0.37534177850244577

# %%
from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=data_imp,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp2=Impute.imputation(mbfile=data_imp,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp2.head()
# Out:
# ...
# Generating walks (CPU: 1): 100%|██████████████████████████████████████████████████████| 20/20 [00:00<00:00, 134.36it/s]
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                    0.000720
# DLF002                0.000720                    0.023493
# DLF003                4.767397                    0.044022
# DLF004                4.174560                    0.000720
# DLF005                0.000720                    0.000720
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.004321                   0.004321
# DLF002                         0.160753                   0.001440
# DLF003                         0.000000                   0.000720
# DLF004                         4.620816                   2.732934
# DLF005                         0.031341                   2.453710
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# ...

# %%
zero_count = (data_imp2 == 0).sum().sum()

# 计算数据框的总元素数量
total_elements = data_imp2.size
# 计算0值的比例
zero_proportion = zero_count / total_elements
zero_proportion
# Out:
# 0.1166185877336009

# %%
data_imp2[data_imp2 == 0] = np.log10(1.01)

# %%
data_imp2.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0915/outptfile_bygemimp_52.csv', index=True) #插补后

# %%
# 15%zero
import pandas as pd
#导入30%的0填充数据
filled_logdata_adjusted=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/0915/filled_logdata_adjusted_2.csv",index_col=0)
filled_logdata_adjusted.head(5)
# Out:
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                         0.0
# DLF002                0.000000                         0.0
# DLF003                4.767397                         0.0
# DLF004                4.174560                         0.0
# DLF005                0.000000                         0.0
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.004321                   0.004321
# DLF002                         0.000000                   0.000000
# DLF003                         0.000000                   0.000000
# DLF004                         4.620816                   2.732934
# DLF005                         0.000000                   2.453710
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# DLF001                      0.0             0.000000               0.000000
# ...

# %%
from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=filled_logdata_adjusted,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp=Impute.imputation(mbfile=filled_logdata_adjusted,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp.head()
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 69.42it/s]
#         s__Eubacterium_rectale  s__Akkermansia_muciniphila  \
# DLF001                0.004321                     0.00072
# DLF002                0.000720                     0.00000
# DLF003                4.767397                     0.00000
# DLF004                4.174560                     0.00072
# DLF005                0.000720                     0.00072
#
#         s__Faecalibacterium_prausnitzii  s__Alistipes_indistinctus  \
# DLF001                         0.004321                   0.004321
# DLF002                         0.000000                   0.001440
# DLF003                         0.000000                   0.000720
# DLF004                         4.620816                   2.732934
# DLF005                         0.000000                   2.453710
#
#         s__Alistipes_putredinis  s__Prevotella_copri  s__Bacteroides_ovatus  \
# ...

# %%
data_imp[data_imp == 0] = np.log10(1.01)

# %%
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0915/outptfile_bygemimp_2.csv', index=True) #插补后

# %% [markdown]
# ## 测序深度0916

# %%
import pandas as pd
#导入30%的0填充数据
filled_logdata_adjusted=pd.read_csv("D:/阅读文献同步文件夹/mbImpute code/0825new/0915/filled_logdata_adjusted_2000_2.csv",index_col=0)
filled_logdata_adjusted.head(5)
# Out:
#          Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# Sample1  0.004321  0.004321  0.004321  0.004321  2.004364  0.004321  0.000000
# Sample2  0.004321  0.004321  0.004321  0.004321  0.004321  0.004321  0.004321
# Sample3  0.699838  0.004321  0.004321  0.004321  1.462548  0.004321  0.004321
# Sample4  0.004321  0.004321  0.004321  0.004321  0.004321  0.004321  0.000000
# Sample5  0.000000  0.004321  0.004321  0.004321  0.004321  0.004321  0.004321
#
#          Feature8  Feature9  Feature10  ...  Feature291  Feature292  \
# Sample1  0.004321  0.004321   0.000000  ...    0.004321    0.004321
# Sample2  0.603144  0.004321   0.004321  ...    0.004321    0.004321
# Sample3  0.004321  0.004321   0.004321  ...    0.004321    0.004321
# Sample4  1.278982  0.004321   0.004321  ...    0.004321    0.004321
# Sample5  0.004321  0.004321   0.000000  ...    0.004321    0.004321
#
#          Feature293  Feature294  Feature295  Feature296  Feature297  \
# ...

# %%
zero_count = (filled_logdata_adjusted == 0).sum().sum()

# 计算数据框的总元素数量
total_elements = filled_logdata_adjusted.size
# 计算0值的比例
zero_proportion = zero_count / total_elements
zero_proportion
# Out:
# 0.059416666666666666

# %%
from MBIMP import Impute

import pandas as pd
graph_adj=Impute.GraphBuild(input_file=filled_logdata_adjusted,k=3) # 从5改成3
cell_emb=Impute.trainCellEmbeddings(graph_adj)
data_imp=Impute.imputation(mbfile=filled_logdata_adjusted,embeddingfile=cell_emb,AdjGraph=graph_adj)
data_imp.head()
# Out:
# ...
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 20/20 [00:00<00:00, 46.16it/s]
#          Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# Sample1  0.004321  0.004321  0.004321  0.004321  2.004364  0.004321  0.003601
# Sample2  0.004321  0.004321  0.004321  0.004321  0.004321  0.004321  0.004321
# Sample3  0.699838  0.004321  0.004321  0.004321  1.462548  0.004321  0.004321
# Sample4  0.004321  0.004321  0.004321  0.004321  0.004321  0.004321  0.002881
# Sample5  0.003241  0.004321  0.004321  0.004321  0.004321  0.004321  0.004321
#
#          Feature8  Feature9  Feature10  ...  Feature291  Feature292  \
# Sample1  0.004321  0.004321   0.028507  ...    0.004321    0.004321
# Sample2  0.603144  0.004321   0.004321  ...    0.004321    0.004321
# Sample3  0.004321  0.004321   0.004321  ...    0.004321    0.004321
# Sample4  1.278982  0.004321   0.004321  ...    0.004321    0.004321
# ...

# %%
zero_count = (data_imp == 0).sum().sum()

# 计算数据框的总元素数量
total_elements = data_imp.size
# 计算0值的比例
zero_proportion = zero_count / total_elements
zero_proportion
# Out:
# 0.00015

# %%
import numpy as np
data_imp[data_imp == 0] = np.log10(1.01)

# %%
data_imp.to_csv('D:/阅读文献同步文件夹/mbImpute code/0825new/0915/outptfile_byGEMimp_2000_2.csv', index=True) #插补
